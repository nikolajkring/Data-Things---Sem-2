# %% [markdown]
# # Evaluating classification models
#
# In this notebook, we will look at how to evaluate classification models in terms of the confusion matrix and measures such as accuracy, precision, and recall, as well as the ROC curve and AUC.
#
# We will, again, use the diabetes dataset that can be used to classify whether people have diabetes.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier

# %%
diab_data = pd.read_csv('diabetes.csv')

# %%
diab_data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
X = diab_data.drop(columns = ["Age", "Outcome"])
y = diab_data["Outcome"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# We will first use our KNN models for $K=5$ and $K=10$ as examples, so let us train them.

# %%
knn5 = KNeighborsClassifier(n_neighbors=5)
knn5.fit(X_train, y_train)
y_train_pred5 = knn5.predict(X_train)
y_test_pred5 = knn5.predict(X_test)

knn10 = KNeighborsClassifier(n_neighbors=10)
knn10.fit(X_train, y_train)
y_train_pred10 = knn10.predict(X_train)
y_test_pred10 = knn10.predict(X_test)

# %% [markdown]
# ## The confusion matrix
#
# We can use the `confusion_matrix` function from the Scikit-learn metrics submodule, to get a confusion matrix.

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test, y_test_pred5)
# Out:
# array([[92, 31],
#        [30, 39]])

# %%
confusion_matrix(y_test, y_test_pred10)
# Out:
# array([[107,  16],
#        [ 34,  35]])

# %% [markdown]
# We can also make it visually more appealing with a heatmap style plot using `ConfusionMatrixDisplay` also from Scikit-learn metrics.

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# %%
ConfusionMatrixDisplay(confusion_matrix(y_test, y_test_pred5)).plot()
plt.show()

# %%
ConfusionMatrixDisplay(confusion_matrix(y_test, y_test_pred10)).plot()
plt.show()

# %% [markdown]
# It looks like the model for $K=10$ make less False Positive predictions (16 instead of 31) than the model for $K=5$. On the other hand, it makes more False Negative predictions (34 instead of 30). Let us calculate the various metrics to make a more detailed comparison.

# %% [markdown]
# If one wants to look at percentages instead, we can normalize the values in the cells to sum to one:

# %%
ConfusionMatrixDisplay(confusion_matrix(y_test, y_test_pred10, normalize='all')).plot()
plt.show()

# %% [markdown]
# ## Evaluation metrics
#
# We can import all the revelant evaluation metrics from Scikit-learn metrics submodule:

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %%
EvaluationScoreDF = pd.DataFrame({"K": [5, 10],
                                  "Accuracy (test)": [accuracy_score(y_test, y_test_pred5), accuracy_score(y_test, y_test_pred10)],
                                  "Precision (test)": [precision_score(y_test, y_test_pred5), precision_score(y_test, y_test_pred10)],
                                  "Recall (test)": [recall_score(y_test, y_test_pred5), recall_score(y_test, y_test_pred10)],
                                  "F1 (test)": [f1_score(y_test, y_test_pred5), f1_score(y_test, y_test_pred10)]})
EvaluationScoreDF
# Out:
#     K  Accuracy (test)  Precision (test)  Recall (test)  F1 (test)
# 0   5         0.682292          0.557143       0.565217   0.561151
# 1  10         0.739583          0.686275       0.507246   0.583333

# %% [markdown]
# We see that the $K=10$ seems slightly better on most evaluation metrics, however, if recall is the most important to us, $K=5$ is actually a better choice.

# %% [markdown]
# ## ROC and AUC evaluation
#
# We will not look at the ROC curve and calculate AUC for the models. For this we will use our logistic regression model as it naturally can give us class probabilities instead hard labels.

# %%
from sklearn import linear_model

# %%
logit_model = linear_model.LogisticRegression()

# %%
X_train = X_train[["Glucose", "BMI"]]
X_test = X_test[["Glucose", "BMI"]]

# %%
logit_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# We want to get the class probabilities (of class 1). We can use the method `.predict_proba` on the logistic model object:

# %%
logit_model.predict_proba(X_test)
# Out:
# array([[0.81920253, 0.18079747],
#        [0.69937823, 0.30062177],
#        [0.8059199 , 0.1940801 ],
#        [0.88151661, 0.11848339],
#        [0.61522455, 0.38477545],
#        [0.73113449, 0.26886551],
#        [0.97601199, 0.02398801],
#        [0.69575188, 0.30424812],
#        [0.42103522, 0.57896478],
#        [0.43252579, 0.56747421],
#        [0.8325353 , 0.1674647 ],
#        [0.1828805 , 0.8171195 ],
#        [0.48455961, 0.51544039],
#        [0.83479919, 0.16520081],
#        [0.91478437, 0.08521563],
#        [0.64011523, 0.35988477],
#        [0.85143022, 0.14856978],
#        [0.90794117, 0.09205883],
#        [0.24349335, 0.75650665],
#        [0.31061343, 0.68938657],
#        [0.85164838, 0.14835162],
#        [0.88658583, 0.11341417],
#        [0.72840564, 0.27159436],
#        [0.83960214, 0.16039786],
#        [0.54961798, 0.45038202],
#        [0.14232986, 0.85767014],
#        [0.86964182, 0.13035818],
#        [0.93788371, 0.06211629],
#        [0.58664121, 0.41335879],
#        [0.89663475, 0.10336525],
#        [0.07287624, 0.92712376],
#        [0.3412942 , 0.6587058 ],
#        [0.12694693, 0.87305307],
#        [0.29182212, 0.70817788],
#        [0.58379378, 0.41620622],
#        [0.37749589, 0.62250411],
#        [0.0992566 , 0.9007434 ],
#        [0.775045  , 0.224955  ],
#        [0.78961981, 0.21038019],
#        [0.37335253, 0.62664747],
#        [0.92670323, 0.07329677],
#        [0.68743935, 0.31256065],
#        [0.71680317, 0.28319683],
#        [0.82290297, 0.17709703],
#        [0.95141859, 0.04858141],
#        [0.37927548, 0.62072452],
#        [0.68090008, 0.31909992],
#        [0.78511429, 0.21488571],
#        [0.87106282, 0.12893718],
#        [0.08634355, 0.91365645],
#        [0.92258387, 0.07741613],
#        [0.52543605, 0.47456395],
#        [0.37808091, 0.62191909],
#        [0.65277622, 0.34722378],
#        [0.73996408, 0.26003592],
#        [0.94135449, 0.05864551],
#        [0.41725828, 0.58274172],
#        [0.99435304, 0.00564696],
#        [0.55293429, 0.44706571],
#        [0.2736206 , 0.7263794 ],
#        [0.39760872, 0.60239128],
#        [0.59345194, 0.40654806],
#        [0.83688227, 0.16311773],
#        [0.90857161, 0.09142839],
#        [0.83993702, 0.16006298],
#        [0.25477727, 0.74522273],
#        [0.93664767, 0.06335233],
#        [0.22570183, 0.77429817],
#        [0.9348603 , 0.0651397 ],
#        [0.12336105, 0.87663895],
#        [0.38451968, 0.61548032],
#        [0.92264191, 0.07735809],
#        [0.93294206, 0.06705794],
#        [0.78953985, 0.21046015],
#        [0.89852759, 0.10147241],
#        [0.70437751, 0.29562249],
#        [0.89982121, 0.10017879],
#        [0.91714313, 0.08285687],
#        [0.74865645, 0.25134355],
#        [0.67934792, 0.32065208],
#        [0.39560356, 0.60439644],
#        [0.78996137, 0.21003863],
#        [0.93928292, 0.06071708],
#        [0.39258459, 0.60741541],
#        [0.65845161, 0.34154839],
#        [0.12066832, 0.87933168],
#        [0.13099124, 0.86900876],
#        [0.65656476, 0.34343524],
#        [0.87152983, 0.12847017],
#        [0.88407274, 0.11592726],
#        [0.89682989, 0.10317011],
#        [0.733022  , 0.266978  ],
#        [0.99546993, 0.00453007],
#        [0.7410035 , 0.2589965 ],
#        [0.46863858, 0.53136142],
#        [0.30356321, 0.69643679],
#        [0.81188517, 0.18811483],
#        [0.86032853, 0.13967147],
#        [0.18871835, 0.81128165],
#        [0.95088901, 0.04911099],
#        [0.30579525, 0.69420475],
#        [0.88014421, 0.11985579],
#        [0.41316512, 0.58683488],
#        [0.3472609 , 0.6527391 ],
#        [0.35270756, 0.64729244],
#        [0.64713283, 0.35286717],
#        [0.66400797, 0.33599203],
#        [0.2243997 , 0.7756003 ],
#        [0.89639924, 0.10360076],
#        [0.71858821, 0.28141179],
#        [0.88684084, 0.11315916],
#        [0.41248143, 0.58751857],
#        [0.98590926, 0.01409074],
#        [0.20529901, 0.79470099],
#        [0.72289612, 0.27710388],
#        [0.59688995, 0.40311005],
#        [0.24348417, 0.75651583],
#        [0.77781279, 0.22218721],
#        [0.91369946, 0.08630054],
#        [0.68326748, 0.31673252],
#        [0.89159485, 0.10840515],
#        [0.70358917, 0.29641083],
#        [0.76426588, 0.23573412],
#        [0.93024184, 0.06975816],
#        [0.56226593, 0.43773407],
#        [0.81714398, 0.18285602],
#        [0.9797447 , 0.0202553 ],
#        [0.37013239, 0.62986761],
#        [0.18735798, 0.81264202],
#        [0.20360156, 0.79639844],
#        [0.33530342, 0.66469658],
#        [0.24363395, 0.75636605],
#        [0.86559438, 0.13440562],
#        [0.64800756, 0.35199244],
#        [0.11087979, 0.88912021],
#        [0.85317839, 0.14682161],
#        [0.76712645, 0.23287355],
#        [0.19226957, 0.80773043],
#        [0.37414866, 0.62585134],
#        [0.97902248, 0.02097752],
#        [0.8565645 , 0.1434355 ],
#        [0.93885285, 0.06114715],
#        [0.67643149, 0.32356851],
#        [0.35596065, 0.64403935],
#        [0.82934682, 0.17065318],
#        [0.83874898, 0.16125102],
#        [0.91919005, 0.08080995],
#        [0.96779872, 0.03220128],
#        [0.62676339, 0.37323661],
#        [0.34404485, 0.65595515],
#        [0.91276601, 0.08723399],
#        [0.79818935, 0.20181065],
#        [0.56649197, 0.43350803],
#        [0.90741142, 0.09258858],
#        [0.99346032, 0.00653968],
#        [0.81833591, 0.18166409],
#        [0.61403377, 0.38596623],
#        [0.56247828, 0.43752172],
#        [0.29050714, 0.70949286],
#        [0.73947531, 0.26052469],
#        [0.58726875, 0.41273125],
#        [0.48351954, 0.51648046],
#        [0.73294732, 0.26705268],
#        [0.97035018, 0.02964982],
#        [0.83686866, 0.16313134],
#        [0.11611081, 0.88388919],
#        [0.91057219, 0.08942781],
#        [0.54692639, 0.45307361],
#        [0.16121483, 0.83878517],
#        [0.66521364, 0.33478636],
#        [0.46020738, 0.53979262],
#        [0.82259567, 0.17740433],
#        [0.68227202, 0.31772798],
#        [0.1877372 , 0.8122628 ],
#        [0.26748766, 0.73251234],
#        [0.85537194, 0.14462806],
#        [0.62990579, 0.37009421],
#        [0.85687   , 0.14313   ],
#        [0.83898223, 0.16101777],
#        [0.62343112, 0.37656888],
#        [0.69327366, 0.30672634],
#        [0.2417068 , 0.7582932 ],
#        [0.73556319, 0.26443681],
#        [0.16165504, 0.83834496],
#        [0.39749345, 0.60250655],
#        [0.84800647, 0.15199353],
#        [0.92607301, 0.07392699],
#        [0.8547427 , 0.1452573 ],
#        [0.24824325, 0.75175675],
#        [0.65096134, 0.34903866],
#        [0.92509016, 0.07490984],
#        [0.87413932, 0.12586068]])

# %% [markdown]
# Note how it returns two columns of probabilities! The first column is the probability of class 0, while the second column is the probabilities of class 1 (note how the rows sum to 1). Thus, to get the probabilities for class 1, we can take the second column (denoted 1 in Python - I think I mixed it up last time):

# %%
y_train_probs = logit_model.predict_proba(X_train)[:,1]
y_train_pred = logit_model.predict(X_train)

y_test_probs = logit_model.predict_proba(X_test)[:,1]
y_test_pred = logit_model.predict(X_test)

y_test_probs
# Out:
# array([0.18079747, 0.30062177, 0.1940801 , 0.11848339, 0.38477545,
#        0.26886551, 0.02398801, 0.30424812, 0.57896478, 0.56747421,
#        0.1674647 , 0.8171195 , 0.51544039, 0.16520081, 0.08521563,
#        0.35988477, 0.14856978, 0.09205883, 0.75650665, 0.68938657,
#        0.14835162, 0.11341417, 0.27159436, 0.16039786, 0.45038202,
#        0.85767014, 0.13035818, 0.06211629, 0.41335879, 0.10336525,
#        0.92712376, 0.6587058 , 0.87305307, 0.70817788, 0.41620622,
#        0.62250411, 0.9007434 , 0.224955  , 0.21038019, 0.62664747,
#        0.07329677, 0.31256065, 0.28319683, 0.17709703, 0.04858141,
#        0.62072452, 0.31909992, 0.21488571, 0.12893718, 0.91365645,
#        0.07741613, 0.47456395, 0.62191909, 0.34722378, 0.26003592,
#        0.05864551, 0.58274172, 0.00564696, 0.44706571, 0.7263794 ,
#        0.60239128, 0.40654806, 0.16311773, 0.09142839, 0.16006298,
#        0.74522273, 0.06335233, 0.77429817, 0.0651397 , 0.87663895,
#        0.61548032, 0.07735809, 0.06705794, 0.21046015, 0.10147241,
#        0.29562249, 0.10017879, 0.08285687, 0.25134355, 0.32065208,
#        0.60439644, 0.21003863, 0.06071708, 0.60741541, 0.34154839,
#        0.87933168, 0.86900876, 0.34343524, 0.12847017, 0.11592726,
#        0.10317011, 0.266978  , 0.00453007, 0.2589965 , 0.53136142,
#        0.69643679, 0.18811483, 0.13967147, 0.81128165, 0.04911099,
#        0.69420475, 0.11985579, 0.58683488, 0.6527391 , 0.64729244,
#        0.35286717, 0.33599203, 0.7756003 , 0.10360076, 0.28141179,
#        0.11315916, 0.58751857, 0.01409074, 0.79470099, 0.27710388,
#        0.40311005, 0.75651583, 0.22218721, 0.08630054, 0.31673252,
#        0.10840515, 0.29641083, 0.23573412, 0.06975816, 0.43773407,
#        0.18285602, 0.0202553 , 0.62986761, 0.81264202, 0.79639844,
#        0.66469658, 0.75636605, 0.13440562, 0.35199244, 0.88912021,
#        0.14682161, 0.23287355, 0.80773043, 0.62585134, 0.02097752,
#        0.1434355 , 0.06114715, 0.32356851, 0.64403935, 0.17065318,
#        0.16125102, 0.08080995, 0.03220128, 0.37323661, 0.65595515,
#        0.08723399, 0.20181065, 0.43350803, 0.09258858, 0.00653968,
#        0.18166409, 0.38596623, 0.43752172, 0.70949286, 0.26052469,
#        0.41273125, 0.51648046, 0.26705268, 0.02964982, 0.16313134,
#        0.88388919, 0.08942781, 0.45307361, 0.83878517, 0.33478636,
#        0.53979262, 0.17740433, 0.31772798, 0.8122628 , 0.73251234,
#        0.14462806, 0.37009421, 0.14313   , 0.16101777, 0.37656888,
#        0.30672634, 0.7582932 , 0.26443681, 0.83834496, 0.60250655,
#        0.15199353, 0.07392699, 0.1452573 , 0.75175675, 0.34903866,
#        0.07490984, 0.12586068])

# %% [markdown]
# To plot the ROC curve, we well use the `roc_curve` from Scikit-learn metrics to calculate the FPR and TPR for us that we can then plot

# %%
from sklearn.metrics import roc_curve, auc

# %%
# Plotting the ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, y_test_probs)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Test Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# We can also get the AUC directly using the `roc_auc_score` function from Scikit-learn:

# %%
from sklearn.metrics import roc_auc_score

# %%
roc_auc_score(y_test, y_test_probs)
# Out:
# 0.777895605043007
